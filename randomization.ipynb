# %%
import random
import json
import pandas as pd

#global variables to be manipulated
stimulus_set = []
relay = 0

#defining stimulus set
vertical_con_list = [
    {"prime":"le", "probe":"le", "congruency":"congruent", "correct_response":"n", "name":"vertical_con_1"},
    {"prime":"fel", "probe":"fel", "congruency":"congruent", "correct_response":"j", "name":"vertical_con_2"}
]
vertical_inc_list = [
    {"prime":"fel", "probe":"le", "congruency":"incongruent", "correct_response":"n", "name":"vertical_incon_1"},
    {"prime":"le", "probe":"fel", "congruency":"incongruent", "correct_response":"j", "name":"vertical_incon_2"}
    
]

horizontal_con_list = [
    {"prime": "bal", "probe": "bal", "congruency":"congruent", "correct_response":"f", "name": "horizontal_con_1"},
    {"prime": "jobb", "probe": "jobb", "congruency":"congruent", "correct_response":"g", "name": "horizontal_con_2"}
    ]
horizontal_incon_list = [
    {"prime": "bal", "probe": "jobb", "congruency":"incongruent", "correct_response":"g", "name": "horizontal_incon_1"},
    {"prime": "jobb", "probe": "bal", "congruency":"incongruent", "correct_response":"f", "name":"horizontal_incon_2"}
]

#grouping congruent and incongruent stimuli together
vertical_group = [vertical_con_list, vertical_inc_list]
horizontal_group = [horizontal_con_list, horizontal_incon_list]

def stimulus_finder(group):
    global stimulus_set
    congruency = random.randint(0,len(group)-1)
    stimulus = random.randint(0,len(group[congruency])-1)
    stimulus_set.append(group[congruency][stimulus])

def group_relay():
    global relay
    if relay == 0:
        stimulus_finder(horizontal_group)
        relay = 1
    else:
        stimulus_finder(vertical_group)
        relay = 0

def set_factory(times):
    for i in range(times):
        group_relay()
trial_rate = []
trial_count = 80
def factor():
    global trial_rate
    global trial_count
    set_factory(trial_count)
    con_count = 0
    incon_count = 0
    for i in stimulus_set:
        if i["congruency"] == "congruent":
            con_count += 1
        elif i["congruency"] == "incongruent":
            incon_count += 1
    con = con_count/trial_count
    incon = incon_count/trial_count
    trial_rate = [con, incon]

match_count = 0
while True:
    if trial_rate==[0.5, 0.5]:
        group_relay()
        trial_block = pd.DataFrame(stimulus_set, columns=["prime", "probe", "congruency", "correct_response"])
        trial_block["previous_congruency"] = trial_block["congruency"].shift(1)
        trial_block["con_pair"] = trial_block["previous_congruency"] + "-" + trial_block["congruency"]
        pair_counts = trial_block ["con_pair"].value_counts()
        if pair_counts["congruent-congruent"] == 20 and pair_counts["congruent-incongruent"] == 20 and pair_counts["incongruent-congruent"] == 20 and pair_counts["incongruent-incongruent"] == 20:
            match_count += 1
            print("Match found: {}".format(match_count))
            print("Correct paircount found, writing...")
            with open("trials.json", "r+") as file:
                #First we load existing data into a dictionary
                file_data = json.load(file)
                #join new_data with file_data inside emp_details
                file_data["trials"].append(stimulus_set)
                #Sets file's current position at offset.
                file.seek(0)
                #convert back to json.
                json.dump(file_data, file)
            
    stimulus_set = []
    factor()
# Out:
# Match found: 1
# Correct paircount found, writing...
# Match found: 2
# Correct paircount found, writing...
# Match found: 3
# Correct paircount found, writing...
# Match found: 4
# Correct paircount found, writing...
# Match found: 5
# Correct paircount found, writing...
# Match found: 6
# Correct paircount found, writing...
# Match found: 7
# Correct paircount found, writing...
# Match found: 8
# Correct paircount found, writing...
# Match found: 9
# Correct paircount found, writing...
# Match found: 10
# Correct paircount found, writing...
# Match found: 11
# Correct paircount found, writing...
# Match found: 12
# Correct paircount found, writing...
# Match found: 13
# Correct paircount found, writing...
# Match found: 14
# Correct paircount found, writing...
# Match found: 15
# Correct paircount found, writing...
# Match found: 16
# Correct paircount found, writing...
# Match found: 17
# Correct paircount found, writing...
# Match found: 18
# Correct paircount found, writing...
# Match found: 19
# Correct paircount found, writing...
# Match found: 20
# Correct paircount found, writing...
# Match found: 21
# Correct paircount found, writing...
# Match found: 22
# Correct paircount found, writing...
# Match found: 23
# Correct paircount found, writing...
# Match found: 24
# Correct paircount found, writing...
# Match found: 25
# Correct paircount found, writing...
# Match found: 26
# Correct paircount found, writing...
# Match found: 27
# Correct paircount found, writing...
# Match found: 28
# Correct paircount found, writing...
# Match found: 29
# Correct paircount found, writing...
# Match found: 30
# Correct paircount found, writing...
# Match found: 31
# Correct paircount found, writing...
# Match found: 32
# Correct paircount found, writing...
# Match found: 33
# Correct paircount found, writing...
# Match found: 34
# Correct paircount found, writing...
# Match found: 35
# Correct paircount found, writing...
# Match found: 36
# Correct paircount found, writing...
# Match found: 37
# Correct paircount found, writing...
# Match found: 38
# Correct paircount found, writing...
# Match found: 39
# Correct paircount found, writing...
# Match found: 40
# Correct paircount found, writing...
# Match found: 41
# Correct paircount found, writing...
# Match found: 42
# Correct paircount found, writing...
# Match found: 43
# Correct paircount found, writing...
# Match found: 44
# Correct paircount found, writing...
# Match found: 45
# Correct paircount found, writing...
# Match found: 46
# Correct paircount found, writing...
# Match found: 47
# Correct paircount found, writing...
# Match found: 48
# Correct paircount found, writing...
# Match found: 49
# Correct paircount found, writing...
# Match found: 50
# Correct paircount found, writing...
# Match found: 51
# Correct paircount found, writing...
# Match found: 52
# Correct paircount found, writing...
# Match found: 53
# Correct paircount found, writing...
# Match found: 54
# Correct paircount found, writing...
# Match found: 55
# Correct paircount found, writing...
# Match found: 56
# Correct paircount found, writing...
# Match found: 57
# Correct paircount found, writing...
# Match found: 58
# Correct paircount found, writing...
# Match found: 59
# Correct paircount found, writing...
# Match found: 60
# Correct paircount found, writing...
# Match found: 61
# Correct paircount found, writing...
# Match found: 62
# Correct paircount found, writing...
# Match found: 63
# Correct paircount found, writing...
# Match found: 64
# Correct paircount found, writing...
# Match found: 65
# Correct paircount found, writing...
# Match found: 66
# Correct paircount found, writing...
# Match found: 67
# Correct paircount found, writing...
# Match found: 68
# Correct paircount found, writing...
# Match found: 69
# Correct paircount found, writing...
# Match found: 70
# Correct paircount found, writing...
# Match found: 71
# Correct paircount found, writing...
# Match found: 72
# Correct paircount found, writing...
# Match found: 73
# Correct paircount found, writing...
# Match found: 74
# Correct paircount found, writing...
# Match found: 75
# Correct paircount found, writing...
# Match found: 76
# Correct paircount found, writing...
# Match found: 77
# Correct paircount found, writing...
# Match found: 78
# Correct paircount found, writing...
# Match found: 79
# Correct paircount found, writing...
# Match found: 80
# Correct paircount found, writing...
# Match found: 81
# Correct paircount found, writing...
# Match found: 82
# Correct paircount found, writing...
# Match found: 83
# Correct paircount found, writing...
# Match found: 84
# Correct paircount found, writing...
# Match found: 85
# Correct paircount found, writing...
# Match found: 86
# Correct paircount found, writing...
# Match found: 87
# Correct paircount found, writing...
# Match found: 88
# Correct paircount found, writing...
# Match found: 89
# Correct paircount found, writing...
# Match found: 90
# Correct paircount found, writing...
# Match found: 91
# Correct paircount found, writing...
# Match found: 92
# Correct paircount found, writing...
# Match found: 93
# Correct paircount found, writing...
# Match found: 94
# Correct paircount found, writing...
# Match found: 95
# Correct paircount found, writing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 88
#      86             file.seek(0)
#      87             #convert back to json.
# ---> 88             json.dump(file_data, file)
#      90 stimulus_set = []
#      91 factor()
#
# File c:\Users\user\anaconda3\envs\randomization\lib\json\__init__.py:180, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
#     179 for chunk in iterable:
# --> 180     fp.write(chunk)
#
# KeyboardInterrupt:
